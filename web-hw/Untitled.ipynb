# %%
import pandas as pd
import numpy as np

# %%
file_to_load = "cities.csv"

# %%
cities = pd.read_csv(file_to_load)
cities
# Out:
#      City_ID                City  Cloudiness Country        Date  Humidity  \
# 0          0        jacareacanga           0      BR  1528902000        62
# 1          1          kaitangata         100      NZ  1528905304        94
# 2          2            goulburn          20      AU  1528905078        91
# 3          3                lata          76      IN  1528905305        89
# 4          4          chokurdakh           0      RU  1528905306        88
# 5          5            martyush          92      RU  1528905306        94
# 6          6              hobart          20      AU  1528902000        87
# 7          7         broken hill           0      AU  1528905311        88
# 8          8           harnosand           0      SE  1528903200        44
# 9          9           tuatapere           0      NZ  1528905312       100
# 10        10        puerto ayora          90      EC  1528902000        69
# ...

# %%
cities.to_html('data.html')
cities.style.set_properties(**{'text-align':'center'})
# Out:
# <style  type="text/css" >
#     #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col0 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col1 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col2 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col3 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col4 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col5 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col6 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col7 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col8 {
#             text-align:  center;
#         }    #T_98659b8a_b78a_11e9_a885_645d86d72b4crow0_col9 {
# ...
